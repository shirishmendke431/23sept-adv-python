# %% [markdown]
# ### Single Inheritance

# %% [markdown]
# - create class person and employee

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        return f" My name is {self.name} and i am {self.age} years old "

# %%
p1 = Person(name = 'seeta', age = 23)

# %%
p1.introduce()
# Out:
# ' My name is seeta and i am 23 years old '

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        return f" My name is {self.name} and i am {self.age} years old "
# employee
class employee(Person):
    def __init__(self,name,age,company):
        super().__init__(name , age )
        self.company = company

# method
    def info(self):
        print(super().introduce())
        return f"I work for {self.company}"

# %%
e1 = employee(name ='sarthak' , age = 34 , company = 'Infosys')

# %%
e1.info()
# Out:
#  My name is sarthak and i am 34 years old
# 'I work for Infosys'

# %%
e1.introduce()
# Out:
# ' My name is sarthak and i am 34 years old '

# %%
e1.info()
# Out:
#  My name is sarthak and i am 34 years old
# 'I work for Infosys'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        return f" My name is {self.name} and i am {self.age} years old "
# employee
class employee(Person):
    def __init__(self,name,age,company):
        super().__init__(name , age )
        self.company = company

# method
    def info(self):
        return f"{super().introduce()} I work for {self.company}"

# %%
e2 = employee(name ='sarthak' , age = 34 , company = 'Infosys')

# %%
e2.info()
# Out:
# ' My name is sarthak and i am 34 years old  I work for Infosys'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        return f" My name is {self.name} and i am {self.age} years old "
# employee
class employee(Person):
    def __init__(self,name,age,company):
        super().__init__(name , age )
        self.company = company

# method
    def info(self):
        return f"{self.introduce()} I work for {self.company}"

# %%
e3 = e2 = employee(name ='sarthak' , age = 34 , company = 'Infosys')

# %%
e3.info()
# Out:
# ' My name is sarthak and i am 34 years old  I work for Infosys'

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def introduce(self):
        return f" My name is {self.name} and i am {self.age} years old "
# employee
class employee(Person):
    def __init__(self,name,age,company):
        super().__init__(name , age )
        self.company = company

# method
    def info(self):
        super().introduce()
        return f"I work for {self.company}"

# %%
e4= employee(name ='sarthak' , age = 34 , company = 'Infosys')

# %%
e4.info()
# Out:
# 'I work for Infosys'

# %%
class Person:
    def __init__(self , name  , age):
        self.name  = name
        self.age  =  age
    def introduce(self):
        print(f"My name  is  {self.name} and i am {self.age} years  old")

#  employee

class Employee(Person):
    def __init__(self,  name  , age  ,  company):
        super().__init__(name  , age)
        self.company  =  company

    #  method
    def info(self):
        super().introduce()
        return  f'  I work for {self.company } '

# %%
E4  =  Employee(name  = 'sarthak' , age =  34  ,  company  =  'Infosys')

# %%
E4.info()
# Out:
# My name  is  sarthak and i am 34 years  old
# '  I work for Infosys '

# %% [markdown]
# ### Multilevel Inheritance

# %%
## create  classes  employee ,  manager  ,  project manager
class Employee:
    def __init__(self  , name  , emp_id):
        self.name =name
        self.emp_id  =  emp_id

    # get info
    def  get_employee_info(self):
        return f' Name : {self.name}  ,  Id  : {self.emp_id} '

# Create  class manager
class Manager(Employee):
    def __init__(self  , name , emp_id  ,  department):
        super().__init__(name  , emp_id)
        self.department  =  department

# get_manager_info
    def get_manager_info(self):
        return  f"{self.get_employee_info()} . Department : {self.department}"
    

    # class project manager class
class Project_Manager(Manager):
    def __init__(self  ,  name  , emp_id , department  ,  Project):
        super().__init__(name  , emp_id  ,  department)
        self.Project  = Project

    # def  get_project manager info

    def get_project_manager_info(self):
        return  f"{self.get_manager_info()}   Project :  {self.Project}"

# %%
e1 = Employee(name= 'umesh' , emp_id= 12)

# %%
e1.get_employee_info()
# Out:
# ' Name : umesh  ,  Id  : 12 '

# %%
e1.get_manager_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 e1.get_manager_info()
#
# AttributeError: 'Employee' object has no attribute 'get_manager_info'

# %%
e1.get_project_manager_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 e1.get_project_manager_info()
#
# AttributeError: 'Employee' object has no attribute 'get_project_manager_info'

# %%
m1 = Manager(name='umesh' , emp_id = 12 , department = 'ds')

# %%
m1.get_manager_info()
# Out:
# ' Name : umesh  ,  Id  : 12  . Department : ds'

# %%
m1.get_employee_info()
# Out:
# ' Name : umesh  ,  Id  : 12 '

# %%
m1.get_manager_info()
# Out:
# ' Name : umesh  ,  Id  : 12  . Department : ds'

# %%
def add(x,y):
    z = x+y
    return z

# %%
a = add(21,2)
print(a)
# Out:
# 23

# %%
pr = Project_Manager(name='umesh' , emp_id = 1 , department = 'ds',Project='house price prediction}')

# %%
pr.get_employee_info()
# Out:
# ' Name : umesh  ,  Id  : 1 '

# %%
pr.get_manager_info()
# Out:
# ' Name : umesh  ,  Id  : 1  . Department : ds'

# %%
pr.get_project_manager_info()
# Out:
# ' Name : umesh  ,  Id  : 1  . Department : ds   Project :  house price prediction}'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hierarchical Inheritance

# %% [markdown]
# create class  user as parent class and admin and RegularUser as child class

# %%
class  User:
    def __init__(self  ,  username  ,  password):
        self.username   =  username
        self.password  =  password

    # def  get_user_info
    def  get_user_info(self):
        return f"username  : {self.username} ,  password :  {self.password}"
    

    # create  class  ADmin
class  Admin(User):
    def __init__(self,  username  ,  password  ,  Access):
        super().__init__(username  , password  )
        self.Access =  Access


    # def Admin_info

    def Admin_info(self):
        print(super().get_user_info())
        return  f"Access : {self.Access}"
    

    ## create class RegularUser

class  RegularUser(User):
    def __init__(self , username  , password  ,  subscription):
        super().__init__(username  , password  )
        self.subscription =  subscription

    
    # def  method

    def  get_RegularUser_info(self):
        print(super().get_user_info())
        return  f"Subscription :  {self.subscription}"

# %%
u1 = User('sarthak' , 'sarthak@123')

# %%
u1.get_user_info()
# Out:
# 'username  : sarthak ,  password :  sarthak@123'

# %%
u1.get_admin_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 u1.get_admin_info()
#
# AttributeError: 'User' object has no attribute 'get_admin_info'

# %%
a1 =  Admin('sarthak' , 'sarthak@123', 'complete')

# %%
a1.get_user_info()
# Out:
# 'username  : sarthak ,  password :  sarthak@123'

# %%
a1.Admin_info()
# Out:
# username  : sarthak ,  password :  sarthak@123
# 'Access : complete'

# %%
RU = RegularUser('sarthak' , 'sarthak@123','True')

# %%
RU.get_user_info()
# Out:
# 'username  : sarthak ,  password :  sarthak@123'

# %%
RU.get_RegularUser_info()
# Out:
# username  : sarthak ,  password :  sarthak@123
# 'Subscription :  True'

# %%
# !pip  install  pydantic
# Out:
# Requirement already satisfied: pydantic in e:\23 sept advance python\repository\venv\lib\site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (0.4.2)

# %%
# !pip install  pydantic email-validator
# Out:
# Requirement already satisfied: pydantic in e:\23 sept advance python\repository\venv\lib\site-packages (2.12.5)
# Collecting email-validator
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\23 sept advance python\repository\venv\lib\site-packages (from pydantic) (0.4.2)
# Collecting dnspython>=2.0.0 (from email-validator)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: idna>=2.0.0 in e:\23 sept advance python\repository\venv\lib\site-packages (from email-validator) (3.11)
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, email-validator
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [email-validator]
#    -------------------- ------------------- 1/2 [email-validator]
#    -------------------- ------------------- 1/2 [email-validator]
#    ---------------------------------------- 2/2 [email-validator]
#
# Successfully installed dnspython-2.8.0 email-validator-2.3.0

# %%
from pydantic  import BaseModel  , EmailStr , Field 
from typing  import  Literal , List

# %%
# create class student by basemodel
name : str
roll_no : int
marks : float
email : EmailStr
Gender : Literal["Male", "Female"]
hobbies : List[str]

# %%
 class Student(BaseModel):
    name  : str = Field(description  =  'Enter name  here' )
    roll_no  :  int =  Field(description  = 'Enter roll  number' ,  gt  =  0)
    marks  :  float  =  Field(description  =  'Enter Marks' ,  gt  =  0 , lt  =  100)
    email  :  EmailStr  =  Field( description  = 'Enter mail  here' ,  max_length  =  50)
    Gender :  Literal["Male" , "Female"] = Field( description  = 'Enter gender')
    Hobbies  : List[str] =  Field( description  = 'Enter hobbies' ,  default_factory= list)

# %%
S1  = Student(name  = 123  ,roll_no  = 12  ,
                marks  =  35,email  = 'example@gmail.com' 
                , Gender  =  'Male' ,  Hobbies = ['swimming']   )
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 S1  = Student(name  = 123  ,roll_no  = 12  ,
#       2                 marks  =  35,email  = 'example@gmail.com'
#       3                 , Gender  =  'Male' ,  Hobbies = ['swimming']   )
#
# File e:\23 sept advance python\repository\venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Student
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %%
S1  = Student(name  = 'Sunita'  ,roll_no  = 12.2  ,
                marks  =  35,email  = 'example@gmail.com' 
                , Gender  =  'male' ,  Hobbies = ['swimming']   )
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 S1  = Student(name  = 'Sunita'  ,roll_no  = 12.2  ,
#       2                 marks  =  35,email  = 'example@gmail.com'
#       3                 , Gender  =  'male' ,  Hobbies = ['swimming']   )
#
# File e:\23 sept advance python\repository\venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 2 validation errors for Student
# roll_no
#   Input should be a valid integer, got a number with a fractional part [type=int_from_float, input_value=12.2, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_from_float
# Gender
#   Input should be 'Male' or 'Female' [type=literal_error, input_value='male', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/literal_error

# %%
S1  = Student(name  = 'Sunita'  ,roll_no  = 12.2  ,
                marks  =  35,email  = 'example@gmail.com' 
                , Gender  =  'male' ,  Hobbies = 'swimming'   )
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 S1  = Student(name  = 'Sunita'  ,roll_no  = 12.2  ,
#       2                 marks  =  35,email  = 'example@gmail.com'
#       3                 , Gender  =  'male' ,  Hobbies = 'swimming'   )
#
# File e:\23 sept advance python\repository\venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 3 validation errors for Student
# roll_no
#   Input should be a valid integer, got a number with a fractional part [type=int_from_float, input_value=12.2, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.12/v/int_from_float
# Gender
#   Input should be 'Male' or 'Female' [type=literal_error, input_value='male', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/literal_error
# Hobbies
#   Input should be a valid list [type=list_type, input_value='swimming', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/list_type

# %%
S1  = Student(name  = 'Sunita'  ,roll_no  = 0  ,
                marks  =  -1,email  = 'example' 
                , Gender  =  'Male' ,  Hobbies = ['swimming']   )
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 S1  = Student(name  = 'Sunita'  ,roll_no  = 0  ,
#       2                 marks  =  -1,email  = 'example'
#       3                 , Gender  =  'Male' ,  Hobbies = ['swimming']   )
#
# File e:\23 sept advance python\repository\venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 3 validation errors for Student
# roll_no
#   Input should be greater than 0 [type=greater_than, input_value=0, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/greater_than
# marks
#   Input should be greater than 0 [type=greater_than, input_value=-1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/greater_than
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='example', input_type=str]

# %%
class Student(BaseModel):
    name  : str = Field(description  =  'Enter name  here' )
    roll_no  :  int =  Field(description  = 'Enter roll  number' ,  gt  =  0)
    marks  :  float  =  Field(description  =  'Enter Marks' ,  gt  =  0 , lt  =  100)
    email  :  EmailStr  =  Field( description  = 'Enter mail  here' ,  max_length  =  50)
    Gender :  Literal["Male" , "Female"] = Field( description  = 'Enter gender')
    Hobbies  : List[str] =  Field( description  = 'Enter hobbies' ,  default_factory= list)


    # create method
    def  Student_info(self):
        print(f'I am  {self.name}')
        print(f'Roll No  : {self.roll_no}')
        print(f'Marks :  {self.marks}')
        print(f'Gender : {self.Gender}')
        print(f'Hobbies :  {self.Hobbies}')

# %%
S2  =  Student(name  =  'sumitra'  , roll_no  =  90  ,  marks  =  45  ,
                 Gender  =  'Female' 
                 , Hobbies  = ['Music' , 'Dancing'] ,
                 email  ='sunitra@gmail.com')

# %%
S2.Student_info()
# Out:
# I am  sumitra
# Roll No  : 90
# Marks :  45.0
# Gender : Female
# Hobbies :  ['Music', 'Dancing']

# %%
class emp:
    def __init__(self):
        self.name = input('enter name here')

# %%
e1 = emp()
e1

# %%
e1.name
# Out:
# ''

# %%
class  emp :
    def __init_(self):
        self.name  =  input('enter name  here')

# %%
e1 =  emp()
e1

# %%
e1.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 e1.name
#
# AttributeError: 'emp' object has no attribute 'name'
